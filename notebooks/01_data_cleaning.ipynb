# %%
import os

base_path = r"D:\AI_projects\mudra_recognition\dataset\raw\Datasets"

train_path = os.path.join(base_path, "train")
test_path = os.path.join(base_path, "test")
val_path = os.path.join(base_path, "valid")

classes = os.listdir(train_path)
print("Mudra classes:")
print(classes)
# Out:
# Mudra classes:
# ['Alapadma', 'Arala', 'Ardhachandra', 'Ardhapathaka', 'Bhramara', 'Chandrakala', 'Chatura', 'Hamsapaksha', 'Hamsasya', 'Kangula', 'Kapittha', 'Kartarimukha', 'Katakamukha', 'Mayura', 'Mrigashirsha', 'Mukula', 'Mushti', 'Padmakosha', 'Pathaka', 'Samdamsha', 'Sarpashirsha', 'Shikhara', 'Shukatunda', 'Simhamukha', 'Suchi', 'Tamrachuda', 'Tripathaka', 'Trishula']

# %%
import os

print(os.listdir(r"D:\AI_projects\mudra_recognition\dataset\raw\Datasets"))
# Out:
# ['test', 'train', 'valid']

# %%
for cls in classes:
    folder = os.path.join(train_path, cls)
    count = len(os.listdir(folder))
    print(cls, ":", count)
# Out:
# Alapadma : 800
# Arala : 800
# Ardhachandra : 800
# Ardhapathaka : 800
# Bhramara : 800
# Chandrakala : 800
# Chatura : 800
# Hamsapaksha : 800
# Hamsasya : 800
# Kangula : 800
# Kapittha : 800
# Kartarimukha : 800
# Katakamukha : 800
# Mayura : 800
# Mrigashirsha : 800
# Mukula : 800
# Mushti : 800
# Padmakosha : 800
# Pathaka : 800
# Samdamsha : 800
# Sarpashirsha : 800
# Shikhara : 800
# Shukatunda : 800
# Simhamukha : 800
# Suchi : 800
# Tamrachuda : 800
# Tripathaka : 800
# Trishula : 800

# %%
import cv2
import matplotlib.pyplot as plt

sample_class = classes[0]
sample_folder = os.path.join(train_path, sample_class)

img_path = os.path.join(sample_folder, os.listdir(sample_folder)[0])

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title(sample_class)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
bad_files = []

for cls in classes:
    folder = os.path.join(train_path, cls)
    
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        
        img = cv2.imread(path)
        
        if img is None:
            bad_files.append(path)

print("Corrupted images:", len(bad_files))
# Out:
# Corrupted images: 0

# %%
#the above cell taking tm time ill count the num of images adn load 10 imgs now later will check the rest images

# %%
import os

for cls in classes:
    folder = os.path.join(train_path, cls)
    print(cls, ":", len(os.listdir(folder)))
# Out:
# Alapadma : 800
# Arala : 800
# Ardhachandra : 800
# Ardhapathaka : 800
# Bhramara : 800
# Chandrakala : 800
# Chatura : 800
# Hamsapaksha : 800
# Hamsasya : 800
# Kangula : 800
# Kapittha : 800
# Kartarimukha : 800
# Katakamukha : 800
# Mayura : 800
# Mrigashirsha : 800
# Mukula : 800
# Mushti : 800
# Padmakosha : 800
# Pathaka : 800
# Samdamsha : 800
# Sarpashirsha : 800
# Shikhara : 800
# Shukatunda : 800
# Simhamukha : 800
# Suchi : 800
# Tamrachuda : 800
# Tripathaka : 800
# Trishula : 800
